# %%
print ("Taş, kağıt, makas oyununa hoşgeldiniz! Kurallar basit: taş makası, makas kağıdı, kağıt da taşı yener!")
print ("Bu oyun en az iki turdan oluşur. İkinci turun sonunda skoru yüksek olan kazanır, eşitlik durumunda oyun devam eder.")

def tas_kagit_makas_GOZDE_TEMIZCIYILMAZ (OYUNCU) :


  import random

options = ("taş", "kağıt", "makas")
devam = ("evet", "hayır")
tur = 0
oyun = 0
skor1 = 0
skor2 = 0
tur += 1
oyun += 1
running = True

while running :

  player = None
  computer = random.choice(options)

  while player not in options :
    player = input ("Lütfen taş, kağıt, makas seçeneklerinden birini giriniz\n")

  print(f"Oyuncunun Seçimi: {player}")
  print(f"Bilgisayarın Seçimi: {computer}")

  if player == computer:
    print("Berabere!")
    print ("Tur", tur, "tamamlandı.")
    print ("OYUNCU:", skor1, "BİLGİSAYAR:", skor2)
    tur += 1

  elif player == "taş" and computer == "makas" :
    print ("Kazandınız!")
    print ("Tur", tur, "tamamlandı.")
    skor1 += 1
    print ("OYUNCU:", skor1, "BİLGİSAYAR:", skor2)
    tur += 1

  elif player == "kağıt" and computer == "taş" :
    print ("Kazandınız!")
    print ("Tur", tur, "tamamlandı.")
    skor1 +=1
    print ("OYUNCU:", skor1, "BİLGİSAYAR:", skor2)
    tur += 1


  elif player == "makas" and computer == "kağıt" :
    print ("Kazandınız!")
    print ("Tur", tur, "tamamlandı.")
    skor1 += 1
    print ("OYUNCU:", skor1, "BİLGİSAYAR:", skor2)
    tur += 1


  else :
    print ("Kaybettiniz!")
    print ("Tur", tur, "tamamlandı.")
    skor2 += 1
    print ("OYUNCU:", skor1, "BİLGİSAYAR:", skor2)
    tur += 1

  player = input ("Lütfen taş, kağıt, makas seçeneklerinden birini giriniz\n")
  print(f"Oyuncunun Seçimi: {player}")
  print(f"Bilgisayarın Seçimi: {computer}")

  if player == computer:
    print("Berabere!")
    print ("Tur", tur, "tamamlandı.")
    print ("OYUNCU:", skor1, "BİLGİSAYAR:", skor2)
    tur += 1
    if (skor1 < skor2 or skor1 > skor2 and tur >= 2) :
      running = False
      print ("Oynadığın için teşekkürler! Oyun", oyun, "sona erdi!")
      devam = input ("Tekrar oynamak ister misiniz?(evet/hayır)\n")
      if devam == "evet" :
        running = True
        tur = 0
        tur += 1
        skor1 = 0
        skor2 = 0
        oyun += 1
      else :
        running = False
        print ("Oynadığın için teşekkürler! Oyun", oyun, "sona erdi!")


  elif player == "taş" and computer == "makas" :
    print ("Kazandınız!")
    print ("Tur", tur, "tamamlandı.")
    skor1 += 1
    print ("OYUNCU:", skor1, "BİLGİSAYAR:", skor2)
    tur += 1
    if (skor1 < skor2 or skor1 > skor2 and tur >= 2) :
      running = False
      print ("Oynadığın için teşekkürler! Oyun", oyun, "sona erdi!")
      devam = input ("Tekrar oynamak ister misiniz?(evet/hayır)\n")
      if devam == "evet" :
        running = True
        tur = 0
        tur += 1
        skor1 = 0
        skor2 = 0
        oyun += 1
      else :
        running = False
        print ("Oynadığın için teşekkürler! Oyun", oyun, "sona erdi!")


  elif player == "kağıt" and computer == "taş" :
    print ("Kazandınız!")
    print ("Tur", tur, "tamamlandı.")
    skor1 +=1
    print ("OYUNCU:", skor1, "BİLGİSAYAR:", skor2)
    tur += 1
    if (skor1 < skor2 or skor1 > skor2 and tur >= 2) :
      running = False
      print ("Oynadığın için teşekkürler! Oyun", oyun, "sona erdi!")
      devam = input ("Tekrar oynamak ister misiniz?(evet/hayır)\n")
      if devam == "evet" :
        running = True
        tur = 0
        tur += 1
        skor1 = 0
        skor2 = 0
        oyun += 1
      else :
        running = False
        print ("Oynadığın için teşekkürler! Oyun", oyun, "sona erdi!")


  elif player == "makas" and computer == "kağıt" :
    print ("Kazandınız!")
    print ("Tur", tur, "tamamlandı.")
    skor1 += 1
    print ("OYUNCU:", skor1, "BİLGİSAYAR:", skor2)
    tur += 1
    if (skor1 < skor2 or skor1 > skor2 and tur >= 2) :
      running = False
      print ("Oynadığın için teşekkürler! Oyun", oyun, "sona erdi!")
      devam = input ("Tekrar oynamak ister misiniz?(evet/hayır)\n")
      if devam == "evet" :
        running = True
        tur = 0
        tur += 1
        skor1 = 0
        skor2 = 0
        oyun += 1
      else :
        running = False
        print ("Oynadığın için teşekkürler! Oyun", oyun, "sona erdi!")


  else :
    print ("Kaybettiniz!")
    print ("Tur", tur, "tamamlandı.")
    skor2 += 1
    print ("OYUNCU:", skor1, "BİLGİSAYAR:", skor2)
    tur += 1
    if (skor1 < skor2 or skor1 > skor2 and tur >= 2) :
     running = False
     print ("Oynadığın için teşekkürler! Oyun", oyun, "sona erdi!")
     devam = input ("Tekrar oynamak ister misiniz?(evet/hayır)\n")
     if devam == "evet" :
       running = True
       tur = 0
       tur += 1
       skor1 = 0
       skor2 = 0
       oyun += 1
     else :
      running = False
      print ("Oynadığın için teşekkürler! Oyun", oyun, "sona erdi!")
# Out:
# Taş, kağıt, makas oyununa hoşgeldiniz! Kurallar basit: taş makası, makas kağıdı, kağıt da taşı yener!
# Bu oyun en az iki turdan oluşur. İkinci turun sonunda skoru yüksek olan kazanır, eşitlik durumunda oyun devam eder.
# Lütfen taş, kağıt, makas seçeneklerinden birini giriniz
# taş
# Oyuncunun Seçimi: taş
# Bilgisayarın Seçimi: taş
# Berabere!
# Tur 1 tamamlandı.
# OYUNCU: 0 BİLGİSAYAR: 0
# Lütfen taş, kağıt, makas seçeneklerinden birini giriniz
# taş
# Oyuncunun Seçimi: taş
# Bilgisayarın Seçimi: taş
# Berabere!
# Tur 2 tamamlandı.
# OYUNCU: 0 BİLGİSAYAR: 0
# Lütfen taş, kağıt, makas seçeneklerinden birini giriniz
# makas
# Oyuncunun Seçimi: makas
# Bilgisayarın Seçimi: taş
# Kaybettiniz!
# Tur 3 tamamlandı.
# OYUNCU: 0 BİLGİSAYAR: 1
# Lütfen taş, kağıt, makas seçeneklerinden birini giriniz
# kağıt
# Oyuncunun Seçimi: kağıt
# Bilgisayarın Seçimi: taş
# Kazandınız!
# Tur 4 tamamlandı.
# OYUNCU: 1 BİLGİSAYAR: 1
# Lütfen taş, kağıt, makas seçeneklerinden birini giriniz
# makas
# ...
